# %%
import numpy as np
import pandas as pd
import pickle
from datetime import datetime

# %%
data = pickle.load(open("./data/filled_data2.pkl", "rb"))

# %%
data
# Out:
#                                                      Page  2015-07-01  \
# 0                 2NE1_zh.wikipedia.org_all-access_spider        18.0
# 1                  2PM_zh.wikipedia.org_all-access_spider        11.0
# 2                   3C_zh.wikipedia.org_all-access_spider         1.0
# 3              4minute_zh.wikipedia.org_all-access_spider        35.0
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         0.0
# 5                 5566_zh.wikipedia.org_all-access_spider        12.0
# 6               91Days_zh.wikipedia.org_all-access_spider         0.0
# 7                A'N'D_zh.wikipedia.org_all-access_spider       118.0
# 8                AKB48_zh.wikipedia.org_all-access_spider         5.0
# 9                ASCII_zh.wikipedia.org_all-access_spider         6.0
# 10               ASTRO_zh.wikipedia.org_all-access_spider         0.0
# 11      Ahq_e-Sports_Club_zh.wikipedia.org_all-access_...         2.0
# ...

# %%
example = data.loc[145057][1:]

# %%
diff = datetime.strptime(example.dropna().index[-1], "%Y-%m-%d") - datetime.strptime(example.dropna().index[0], "%Y-%m-%d")
diff.days
# type(datetime.strptime(example.dropna().index[-1], "%Y-%m-%d"))
# datetime.strptime(example.dropna().index[-1], "%Y-%m-%d")
# Out:
# 6

# %%
example.dropna()
# Out:
# 2016-12-17    21
# 2016-12-22     0
# 2016-12-23     0
# Name: 145057, dtype: object

# %%
data.loc[145062][0]
# Out:
# 'Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider'

# %%
truths = ['Liverpool_F.C._en' in page for page in data["Page"]]
# for page in data["Page"]:
#     page in 'Francisco_el_matemático'
np.array(truths).sum()
for page in data[(truths)]["Page"]:
    print(page)
data[(truths)]
# Out:
# Liverpool_F.C._en.wikipedia.org_desktop_all-agents
# Liverpool_F.C._en.wikipedia.org_all-access_spider
# Liverpool_F.C._en.wikipedia.org_all-access_all-agents
# Liverpool_F.C._en.wikipedia.org_mobile-web_all-agents
#                                                     Page  2015-07-01  \
# 9731   Liverpool_F.C._en.wikipedia.org_desktop_all-ag...     12463.0
# 33601  Liverpool_F.C._en.wikipedia.org_all-access_spider       226.0
# 38523  Liverpool_F.C._en.wikipedia.org_all-access_all...     21164.0
# 74062  Liverpool_F.C._en.wikipedia.org_mobile-web_all...      8292.0
#
#        2015-07-02  2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  \
# 9731       7919.0      6714.0      5477.0      5158.0      8661.0      7870.0
# 33601       100.0       150.0       108.0       166.0       192.0       144.0
# 38523     13970.0     12002.0     10535.0     10146.0     15018.0     13342.0
# 74062      5835.0      5049.0      4836.0      4796.0      6090.0      5256.0
#
# ...

# %%
data.fillna(0, inplace = True)

# %%
keys = pd.read_csv("../data/key_1.csv")

# %%
truths2 = ['Francisco_el_matemático' in page for page in keys["Page"]]
np.array(truths).sum()
for page in keys[(truths2)]["Page"]:
    print(page)
keys[(truths2)]
# Out:
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-01
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-02
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-03
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-04
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-05
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-06
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-07
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-08
# Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_all-agents_2017-01-09
# ...
